# %%
import geopandas as gpd

gdf = gpd.read_file('/Users/simon/Work/Mars/SIM3292_MarsGlobalGeologicGIS_20M/SIM3292_Shapefiles/SIM3292_Global_Geology.shp')

gdf
# Out:
#       OBJECTID    Shape_Leng    Shape_Area  Unit  \
# 0            1  1.004969e+07  4.450246e+11  lApc
# 1            2  1.357599e+06  3.214948e+10   Hpe
# 2            3  2.575993e+06  7.040982e+10    Hp
# 3            4  6.740798e+05  1.191163e+10   Hpe
# 4            5  4.154933e+06  1.652814e+11    Hp
# ...        ...           ...           ...   ...
# 1306      1307  5.519816e+06  2.300772e+11  lApd
# 1307      1308  3.677311e+06  7.461851e+10   Hpu
# 1308      1309  1.850125e+07  6.258272e+11   Apu
# 1309      1310  9.681803e+06  2.911192e+11   Apu
# 1310      1311  2.332588e+07  1.839820e+12  lApc
#
#                              UnitDesc  SphArea_km  \
# 0       Late Amazonian polar cap unit   103642.00
# 1        Hesperian polar edifice unit    15347.10
# 2                Hesperian polar unit    33723.60
# 3        Hesperian polar edifice unit     6217.34
# 4                Hesperian polar unit    83363.70
# ...                               ...         ...
# ...

# %%
gdf.plot(column='Unit')
# Out:
# <AxesSubplot:>

# %%
gdf.UnitDesc.value_counts()
# Out:
# Amazonian and Hesperian impact unit                  342
# Late Noachian highland unit                          292
# Early Noachian highland unit                         112
# Middle Noachian highland unit                         99
# Hesperian and Noachian transition unit                46
# Late Hesperian transition unit                        28
# Middle Amazonian lowland unit                         26
# Noachian highland edifice unit                        23
# Early Hesperian volcanic unit                         23
# Early Hesperian highland unit                         21
# Early Hesperian transition unit                       20
# Amazonian and Noachian apron unit                     17
# Hesperian transition unit                             16
# Hesperian transition undivided unit                   16
# Noachian highland undivided unit                      16
# Middle Noachian highland massif unit                  15
# ...

# %%
gdf['Age'] = ""
gdf['Age'].loc[gdf['UnitDesc'].str.contains('Hesp')] = 'Hesperian'
gdf['Age'].loc[gdf['UnitDesc'].str.contains('Amaz')] = 'Amazonian'
gdf['Age'].loc[gdf['UnitDesc'].str.contains('Noach')] = 'Noachian'

gdf
#tmp = gdf.dissolve(by='Unit')

#tmp.plot(column='UnitDesc')
# Out:
# /opt/anaconda3/envs/pygmt/lib/python3.8/site-packages/pandas/core/indexing.py:1636: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#       OBJECTID    Shape_Leng    Shape_Area  Unit  \
# 0            1  1.004969e+07  4.450246e+11  lApc
# 1            2  1.357599e+06  3.214948e+10   Hpe
# 2            3  2.575993e+06  7.040982e+10    Hp
# 3            4  6.740798e+05  1.191163e+10   Hpe
# 4            5  4.154933e+06  1.652814e+11    Hp
# ...        ...           ...           ...   ...
# 1306      1307  5.519816e+06  2.300772e+11  lApd
# 1307      1308  3.677311e+06  7.461851e+10   Hpu
# 1308      1309  1.850125e+07  6.258272e+11   Apu
# 1309      1310  9.681803e+06  2.911192e+11   Apu
# 1310      1311  2.332588e+07  1.839820e+12  lApc
#
# ...

# %%
tmp = gdf.dissolve(by='Age')

tmp
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/envs/pygmt/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-c2485cd0e079> in <module>
# ...

# %%
tmp.plot(column='Age', legend=True)
# Out:
#                                                     geometry  OBJECTID  \
# Age
# Amazonian  MULTIPOLYGON (((54.38479 -89.99997, 53.81441 -...         1
# Hesperian  MULTIPOLYGON (((94.18004 -77.14730, 94.18898 -...         2
# Noachian   MULTIPOLYGON (((179.99966 -68.61080, 179.99966...         7
#
#              Shape_Leng    Shape_Area  Unit                       UnitDesc  \
# Age
# Amazonian  1.004969e+07  4.450246e+11  lApc  Late Amazonian polar cap unit
# Hesperian  1.357599e+06  3.214948e+10   Hpe   Hesperian polar edifice unit
# Noachian   2.309327e+06  6.433457e+10   lNh    Late Noachian highland unit
#
#            SphArea_km
# Age
# Amazonian    103642.0
# Hesperian     15347.1
# Noachian      34697.7
